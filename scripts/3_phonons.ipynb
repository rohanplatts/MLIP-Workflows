# %%
import sys
from ase import Atoms
import numpy as np
from pathlib import Path
import os
from ase.build import bulk
from ase.optimize import BFGS
from ase.visualize import view
from mace.calculators import mace_mp
from ase.build import graphene
from ase.build import bulk
from ase.calculators.emt import EMT
import json
from ase.io import read
from ase.build import make_supercell
from ase import Atoms
import warnings 
from ase.phonons import Phonons
import matplotlib.pyplot as plt
import shutil
warnings.filterwarnings(
    "ignore",
    message=r"You are using `torch.load` with `weights_only=False`.*",
    category=FutureWarning,
)

# %%
# ———————————— PARAMETERS
material = 'nv_diamond' # could be diamond, nv_diamond, hbn, hbn_c2
# ————————————————————————

def place_nv_diamond(atoms):
    # 1. Grab scaled positions and symbols
    frac = atoms.get_scaled_positions(wrap=True)
    symbols = np.array(atoms.get_chemical_symbols())
    c_inds = np.where(symbols == 'C')[0]
    
    # 2. Identify the Carbon closest to the center to be our Nitrogen
    dm = frac[c_inds] - 0.5
    dm -= np.round(dm)
    n_idx = c_inds[np.argmin(np.linalg.norm(dm, axis=1))]
    
    # 3. Find its nearest neighbor to become the Vacancy
    # get_distances is much cleaner than manual norm for bulk
    dists = atoms.get_distances(n_idx, c_inds, mic=True)
    
    # Ignore the atom itself (distance 0) to find the neighbor
    dists[c_inds == n_idx] = np.inf
    v_idx = c_inds[np.argmin(dists)]
    
    # 4. Apply changes
    atoms[n_idx].symbol = 'N'
    # Use pop for the vacancy so the index shifts are handled by ASE
    atoms.pop(v_idx)
    
    print(f"NV Center: N placed at {n_idx}, Vacancy created at {v_idx}")
    return atoms

def place_cc_dimer_hbn(atoms):
    
    frac = atoms.get_scaled_positions(wrap=True)
    symbols = np.array(atoms.get_chemical_symbols())
    
    # Find the Boron closest to the fractional center (0.5, 0.5, 0.5)
    b_inds = np.where(symbols == 'B')[0]
    dm = frac[b_inds] - 0.5
    dm -= np.round(dm) # Minimum Image Convention 
    iB = b_inds[np.argmin(np.linalg.norm(dm, axis=1))]
    
    # 3. Find the closest Nitrogen in the same plane
    n_inds = np.where(symbols == 'N')[0]
    # Filter for same z-layer
    same_layer = n_inds[np.isclose(frac[n_inds, 2], frac[iB, 2], atol=1e-4)]
    
    # Find bond partner using MIC distances in Cartesian space
    d_bn = frac[same_layer] - frac[iB]
    d_bn -= np.round(d_bn)
    d_cart = d_bn @ atoms.cell
    iN = same_layer[np.argmin(np.linalg.norm(d_cart, axis=1))]
    
    # 4. Swap to Carbon
    atoms[iB].symbol = 'C'
    atoms[iN].symbol = 'C'
    
    print(f"hBN Dimer: Replaced B[{iB}] and N[{iN}]")
    return atoms

def get_material():
    if material == 'diamond':
        atoms = bulk('C', 'diamond', a=3.567) # Pure diamond reference
        # we have a poscar file for this however it is inbuilt.
        #atoms = read(r"C:\Users\rnpla\Desktop\2026\mlip_phonons\input_files\C.poscar")
        supercell_matrix = np.diag([1,1,1])
        supercell = make_supercell(atoms, supercell_matrix)
    elif material == 'nv_diamond':
        atoms = bulk('C', 'diamond', a=3.567)
        supercell_matrix = np.diag([4,4,4])
        supercell = make_supercell(atoms, supercell_matrix)
        supercell = place_nv_diamond(supercell)
        supercell = supercell[np.argsort(supercell.get_chemical_symbols())]
    elif material == 'hbn':
        # load the unit cell from materials projet:
        # the BN.poscar was found here: 
        # https://next-gen.materialsproject.org/materials/mp-984?formula=BN
        # the materials project defaults to exporting .poscar to be read by vasp 
        atoms = read(r"C:\Users\rnpla\Desktop\2026\mlip_phonons\input_files\BN.poscar")
        supercell_matrix = np.diag([1,1,1])
        supercell = make_supercell(atoms, supercell_matrix)
        supercell = supercell[np.argsort(supercell.get_chemical_symbols())]
    elif material == 'hbn_c2':
        atoms = read(r"C:\Users\rnpla\Desktop\2026\mlip_phonons\input_files\BN.poscar")
        supercell_matrix = np.diag([4,4,4])
        supercell = make_supercell(atoms, supercell_matrix)
        supercell = place_cc_dimer_hbn(supercell)
        supercell = supercell[np.argsort(supercell.get_chemical_symbols())]
        # if we are dealing with monolayer version of hBN we will need the vacuum gap:
        #supercell.center(vacuum=20, axis=2) # 20 angstroms is far enough.
    else:
        raise ValueError("material not recognised")
    view(supercell)
    return atoms, supercell, supercell_matrix

atoms, supercell, supercell_matrix = get_material()
# Out:
# NV Center: N placed at 84, Vacancy created at 83

# %%
from ase.calculators.emt import EMT
from mace.calculators import mace_mp

# ———————————— PARAMETERS
calculator = "small-omat-0" # from mace_mp
# ————————————————————————

def get_calc_object():
    if calculator == "small-omat-0":
        return mace_mp(model=calculator, device="cuda", default_dtype="float64")

mlip_calc = get_calc_object()
supercell.calc = mlip_calc

opt = BFGS(supercell, trajectory='defect_relax.traj')
opt.run(fmax=0.01)  # fmax=0.01 is a good standard for phonons
print("Relaxation complete")
# Out:
# Using model under Academic Software License (ASL) license, see https://github.com/gabor1/ASL
#  To use this model you accept the terms of the license.
# Using Materials Project MACE for MACECalculator with C:\Users\rnpla\.cache\mace/maceomat0smallmodel
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# Using head omat_pbe out of ['omat_pbe']
#       Step     Time          Energy          fmax
# BFGS:    0 19:10:55      -34.944308        0.000000
# Relaxation complete

# %%
# ———————————— PARAMETERS
# ————————————————————————
from ase.filters import ExpCellFilter

def get_kpath():
    """
    returns the k-points and path as a string. no breaks to dentoe 
    jumps required on input. to add another material provide path and k-coordinate details
    """
    if material == 'diamond' or material == 'nv_diamond': 
        # k-point path for structure
        # AFLOW Standard Paths, taken from W. Setyawan and S. Curtarolo https://www.sciencedirect.com/science/article/pii/S0927025610002697 
        # Diamond (fcc)
        # G-X-W-K-G-L-U-W-L-K; U-X (';' is a jump)
        points = {
        'G': [0.0, 0.0, 0.0],
        'X': [0.5, 0.0, 0.5],
        'W': [0.5, 0.25, 0.75],
        'K': [0.375, 0.375, 0.75],
        'L': [0.5, 0.5, 0.5],
        'U': [0.625, 0.25, 0.625]
        } 
        k_path = "GXWKGLUWLK" # diamond
    elif material == 'hbn' or material == 'hbn_c2':
        # hBN (HEX)
        # G-M-K-G-A-L-H-A
        # this can be used for the monolayer, as that is simply GMKG
        points = {
            'G': [0.0, 0.0, 0.0],
            'M': [0.5, 0.0, 0.0],
            'K': [1/3, 1/3, 0.0],
            'A': [0.0, 0.0, 0.5],
            'L': [0.5, 0.0, 0.5],
            'H': [1/3, 1/3, 0.5]
        }
        #k_path = "GMKG" # hbn monolayer
        k_path = "GMKGALHA" # hbn bulk 
    else:
        raise ValueError
    return points, k_path

points, k_path = get_kpath()

def get_phonons():
    import numpy as np
    # clear the name from cache so 'Phonons' does not get confused.
    if os.path.exists(material):
        shutil.rmtree(material)

    # supercell sizing has been handled already. we want the phonons of the supercell so pass 'supercell' in. (note it is relaxed)
    if not (supercell_matrix == np.eye(3)).all():
        size = (1, 1, 1)
    else:
        size = (6,6,6)
    atoms.calc = mlip_calc
    #ecf = ExpCellFilter(atoms)          # relax cell + positions
    #opt = BFGS(ecf, trajectory="cell_relax.traj")
    #opt.run(fmax=0.01)

    ph = Phonons(supercell, mlip_calc, supercell=size, delta=0.01, name = material)
    ph.run() # phonons object
    ph.read(acoustic=True)
    ph.clean()
    print('Obtained Phonons')

    # define the k-point path. this should be relative to the unit_cell, which we stored as atoms.
    path = atoms.cell.bandpath(k_path, npoints=400, special_points=points) # bandpath 
    bs = ph.get_band_structure(path) # band_structure 
    dos = ph.get_dos(kpts=(20, 20, 20)).sample_grid(npts=500, width=1e-3) # density of states
    import numpy as np

    emin_ev = np.min(np.asarray(bs.energies))
    print("Finished getting band structure and DOS. Details:")
    print("Minimum band energy (eV):", emin_ev)
    print("Minimum frequency (THz):", emin_ev * 241.79893)

    print('Obtained DOS')
    E = np.array(dos.get_energies()) # eV
    g = np.array(dos.get_weights()) # states / eV

    modes = np.trapz(g, E) # number of modes
    print("∫DOS dE =", modes)
    print("Expected =", 3 * len(supercell)) # supercell is the atoms you passed to Phonons
    
    return ph, bs, dos, path
ph, bs, dos, path = get_phonons() # = phonons, band structure, density of states, bandpath 

def get_plot_dispersion_curve():
    if material == 'diamond' or material == 'hbn':
        # Plotting logic
        fig = plt.figure(figsize=(9, 5))

        # convert to thz 
        unit_conversion = 241.798
        emax_ev = max(
            np.max(dos.get_energies()),
            np.max(np.asarray(bs.energies))
        ) * 1.1  # 3% headroom

        # Band Structure Axis
        ax = fig.add_axes([0.12, 0.1, 0.60, 0.8])
        bs.plot(ax=ax, emin=0.0, emax=emax_ev)

        # Convert Y-ticks to THz for readability
        ticks = ax.get_yticks()
        ax.set_yticklabels([f"{t * unit_conversion:.0f}" for t in ticks])
        ax.set_ylabel("Frequency (THz)", fontsize=14)

        # DOS Axis
        dosax = fig.add_axes([0.75, 0.1, 0.20, 0.8])
        dosax.fill_between(
            dos.get_weights(),
            dos.get_energies() * unit_conversion, # Scale energies to THz
            y2=0,
            color='grey', alpha=0.5
        )

        dosax.set_ylim(0, emax_ev*unit_conversion) # Now using the THz ceilings
        dosax.set_yticks([])
        dosax.set_xlabel('DOS', fontsize=14)
        fig.suptitle(f'{material} Phonon Dispersion and DOS', fontsize=16, y = 0.98)
        fig.savefig(f'{material}_Phonon.png', dpi=300)
    else:
        pass
    pass

get_plot_dispersion_curve()

EV_TO_THz = 241.79893 # 1 eV = 241.79893 THz (E = h nu)
THz_TO_CM1 = 33.35641 # 1 THz ≈ 33.35641 cm^-1

def compute_phonon_dos(ph, kpts=(12, 12, 12), npts=4000, width_thz=0.25):
    """
    Returns (freqs_thz, dos_states_per_thz).

    ph: an ASE Phonons object AFTER ph.run() and ph.read(...)
    kpts: Monkhorst-Pack grid used for DOS integration over the BZ
    width_thz: Gaussian broadening in THz (more intuitive than eV)
    """
    width_ev = width_thz / EV_TO_THz

    dos = ph.get_dos(kpts=kpts).sample_grid(npts=npts, width=width_ev)

    energies_ev = np.asarray(dos.get_energies())
    weights_per_ev = np.asarray(dos.get_weights())

    # Convert to frequency axis
    freqs_thz = energies_ev * EV_TO_THz

    # If plotting vs THz, convert DOS units: g(ν) = g(E) * dE/dν = g(E) / (dν/dE) = g(E) / EV_TO_THz
    weights_per_thz = weights_per_ev / EV_TO_THz

    # Guard against tiny negative frequencies (numerical noise)
    mask = freqs_thz >= -1e-6
    freqs_thz = freqs_thz[mask]
    weights_per_thz = weights_per_thz[mask]
    freqs_thz = np.clip(freqs_thz, 0.0, None)

    return freqs_thz, weights_per_thz

def plot_phonon_dos(freqs_thz, dos_states_per_thz, out_png,
                    title=None, emax_thz=None, dpi=450):
    """
    High-quality single-panel DOS plot: DOS on x-axis, frequency on y-axis (THz),
    with a secondary y-axis in cm^-1.
    """
    if emax_thz is None:
        emax_thz = float(np.max(freqs_thz)) * 1.02

    fig, ax = plt.subplots(figsize=(4.6, 6.2), constrained_layout=True)

    # Curve + filled area (no explicit color set; matplotlib defaults)
    ax.plot(dos_states_per_thz, freqs_thz, linewidth=1.2)
    ax.fill_betweenx(freqs_thz, 0.0, dos_states_per_thz, alpha=0.25)

    ax.set_xlabel("Phonon DOS (states / THz)")
    ax.set_ylabel("Frequency (THz)")
    ax.set_ylim(0.0, emax_thz)
    ax.set_xlim(left=0.0)

    ax.grid(True, which="both", alpha=0.25)
    ax.tick_params(direction="in", top=True, right=True)

    if title:
        ax.set_title(title)

    # Secondary axis in cm^-1
    ax2 = ax.twinx()
    y0, y1 = ax.get_ylim()
    ax2.set_ylim(y0 * THz_TO_CM1, y1 * THz_TO_CM1)
    ax2.set_ylabel(r"Frequency (cm$^{-1}$)")
    ax2.tick_params(direction="in", top=True, right=True)

    fig.savefig(out_png, dpi=dpi)
    

freqs_thz, g_thz = compute_phonon_dos(ph, kpts=(12,12,12), npts=5000, width_thz=0.25)
plot_phonon_dos(freqs_thz, g_thz,
                out_png=f"{material}_DOS.png",
                title=f"{material} phonon DOS | k={12}^3 | σ=0.25 THz",
                emax_thz=50.0)
# Out:
# C:\jltmp\ipykernel_22736\4052999171.py:56: DeprecationWarning: Use FrechetCellFilter for better convergence w.r.t. cell variables.
#   ecf = ExpCellFilter(atoms)          # relax cell + positions
#       Step     Time          Energy          fmax
# BFGS:    0 19:39:51      -18.022687        0.323290
# BFGS:    1 19:39:51      -18.023964        0.140333
# BFGS:    2 19:39:51      -18.024255        0.000883
# Obtained Phonons
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.01,  0.00,  0.01) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.02,  0.00,  0.02) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.02,  0.00,  0.02) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.03,  0.00,  0.03) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.04,  0.00,  0.04) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.05,  0.00,  0.05) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.05,  0.00,  0.05) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.06,  0.00,  0.06) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.07,  0.00,  0.07) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.08,  0.00,  0.08) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.08,  0.00,  0.08) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.09,  0.00,  0.09) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.10,  0.00,  0.10) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.11,  0.00,  0.11) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.12,  0.00,  0.12) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.12,  0.00,  0.12) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.13,  0.00,  0.13) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.14,  0.00,  0.14) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.15,  0.00,  0.15) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.15,  0.00,  0.15) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.16,  0.00,  0.16) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.17,  0.00,  0.17) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.18,  0.00,  0.18) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.18,  0.00,  0.18) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.19,  0.00,  0.19) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.20,  0.00,  0.20) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.21,  0.00,  0.21) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.22,  0.00,  0.22) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.22,  0.00,  0.22) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.23,  0.00,  0.23) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.24,  0.00,  0.24) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.25,  0.00,  0.25) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.25,  0.00,  0.25) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.26,  0.00,  0.26) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.27,  0.00,  0.27) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.28,  0.00,  0.28) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.28,  0.00,  0.28) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.29,  0.00,  0.29) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.30,  0.00,  0.30) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.31,  0.00,  0.31) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.32,  0.00,  0.32) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.32,  0.00,  0.32) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.33,  0.00,  0.33) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.34,  0.00,  0.34) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.35,  0.00,  0.35) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.35,  0.00,  0.35) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.36,  0.00,  0.36) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.37,  0.00,  0.37) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.38,  0.00,  0.38) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.38,  0.00,  0.38) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.39,  0.00,  0.39) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.40,  0.00,  0.40) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.41,  0.00,  0.41) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.42,  0.00,  0.42) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.42,  0.00,  0.42) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.43,  0.00,  0.43) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.44,  0.00,  0.44) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.45,  0.00,  0.45) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.45,  0.00,  0.45) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.00,  0.46) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.47,  0.00,  0.47) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.48,  0.00,  0.48) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.48,  0.00,  0.48) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.49,  0.00,  0.49) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.00,  0.50) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.01,  0.51) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.02,  0.52) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.02,  0.52) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.03,  0.53) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.04,  0.54) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.05,  0.55) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.05,  0.55) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.06,  0.56) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.07,  0.57) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.08,  0.58) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.09,  0.59) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.09,  0.59) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.10,  0.60) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.11,  0.61) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.12,  0.62) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.12,  0.62) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.13,  0.63) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.14,  0.64) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.15,  0.65) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.16,  0.66) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.16,  0.66) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.17,  0.67) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.18,  0.68) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.19,  0.69) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.20,  0.70) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.20,  0.70) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.21,  0.71) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.22,  0.72) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.23,  0.73) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.23,  0.73) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.24,  0.74) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.50,  0.25,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.49,  0.26,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.49,  0.26,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.48,  0.27,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.48,  0.27,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.47,  0.28,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.47,  0.28,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.29,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.45,  0.30,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.45,  0.30,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.44,  0.31,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.44,  0.31,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.43,  0.32,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.43,  0.32,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.42,  0.33,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.41,  0.34,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.41,  0.34,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.40,  0.35,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.40,  0.35,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.39,  0.36,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.39,  0.36,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.38,  0.37,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.38,  0.38,  0.75) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.37,  0.37,  0.74) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.36,  0.36,  0.73) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.36,  0.36,  0.72) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.35,  0.35,  0.71) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.35,  0.35,  0.70) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.34,  0.34,  0.69) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.34,  0.34,  0.68) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.33,  0.33,  0.66) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.33,  0.33,  0.65) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.32,  0.32,  0.64) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.32,  0.32,  0.63) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.31,  0.31,  0.62) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.31,  0.31,  0.61) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.30,  0.30,  0.60) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.29,  0.29,  0.59) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.29,  0.29,  0.58) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.28,  0.28,  0.57) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.28,  0.28,  0.56) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.27,  0.27,  0.55) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.27,  0.27,  0.54) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.26,  0.26,  0.53) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.26,  0.26,  0.51) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.25,  0.25,  0.50) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.25,  0.25,  0.49) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.24,  0.24,  0.48) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.24,  0.24,  0.47) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.23,  0.23,  0.46) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.23,  0.23,  0.45) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.22,  0.22,  0.44) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.21,  0.21,  0.43) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.21,  0.21,  0.42) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.20,  0.20,  0.41) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.20,  0.20,  0.40) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.19,  0.19,  0.39) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.19,  0.19,  0.38) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.18,  0.18,  0.36) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.18,  0.18,  0.35) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.17,  0.17,  0.34) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.17,  0.17,  0.33) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.16,  0.16,  0.32) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.16,  0.16,  0.31) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.15,  0.15,  0.30) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.14,  0.14,  0.29) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.14,  0.14,  0.28) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.13,  0.13,  0.27) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.13,  0.13,  0.26) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.12,  0.12,  0.25) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.12,  0.12,  0.24) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.11,  0.11,  0.23) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.11,  0.11,  0.21) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.10,  0.10,  0.20) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.10,  0.10,  0.19) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.09,  0.09,  0.18) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.09,  0.09,  0.17) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.08,  0.08,  0.16) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.08,  0.08,  0.15) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.07,  0.07,  0.14) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.06,  0.06,  0.13) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.06,  0.06,  0.12) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.05,  0.05,  0.11) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.05,  0.05,  0.10) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.04,  0.04,  0.09) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.04,  0.04,  0.07) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.03,  0.03,  0.06) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.03,  0.03,  0.05) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.02,  0.02,  0.04) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.02,  0.02,  0.03) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.01,  0.01,  0.02) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.01,  0.01,  0.01) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.01,  0.01,  0.01) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.03,  0.03,  0.03) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.05,  0.05,  0.05) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.06,  0.06,  0.06) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.07,  0.07,  0.07) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.08,  0.08,  0.08) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.09,  0.09,  0.09) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.10,  0.10,  0.10) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.11,  0.11,  0.11) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.11,  0.11,  0.11) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.12,  0.12,  0.12) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.13,  0.13,  0.13) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.14,  0.14,  0.14) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.15,  0.15,  0.15) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.16,  0.16,  0.16) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.17,  0.17,  0.17) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.18,  0.18,  0.18) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.18,  0.18,  0.18) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.19,  0.19,  0.19) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.20,  0.20,  0.20) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0
; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.46, -0.04) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.46,  0.04) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.46,  0.12) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.46,  0.21) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.46,  0.29) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.46,  0.38) ; (omega_q = 2.631e-06*i)
# WARNING, 3 imaginary frequencies at q = ( 0.46,  0.46,  0.46) ; (omega_q = 2.631e-06*i)

# %%
# Out:
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04, -0.46) ; (omega_q = 2.304e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04, -0.38) ; (omega_q = 2.321e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04, -0.29) ; (omega_q = 2.342e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04, -0.21) ; (omega_q = 2.363e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04, -0.12) ; (omega_q = 2.379e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04, -0.04) ; (omega_q = 2.388e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04,  0.04) ; (omega_q = 2.388e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04,  0.12) ; (omega_q = 2.379e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04,  0.21) ; (omega_q = 2.363e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04,  0.29) ; (omega_q = 2.342e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04,  0.38) ; (omega_q = 2.321e-01*i)
# WARNING, 2 imaginary frequencies at q = (-0.04,  0.04,  0.46) ; (omega_q = 2.304e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04, -0.46) ; (omega_q = 2.304e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04, -0.38) ; (omega_q = 2.321e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04, -0.29) ; (omega_q = 2.342e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04, -0.21) ; (omega_q = 2.363e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04, -0.12) ; (omega_q = 2.379e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04, -0.04) ; (omega_q = 2.388e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04,  0.04) ; (omega_q = 2.388e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04,  0.12) ; (omega_q = 2.379e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04,  0.21) ; (omega_q = 2.363e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04,  0.29) ; (omega_q = 2.342e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04,  0.38) ; (omega_q = 2.321e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04, -0.04,  0.46) ; (omega_q = 2.304e-01*i)
